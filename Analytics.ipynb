# %% [markdown]
# <a href="https://colab.research.google.com/github/kkhrystynaa/Khrystyna_Kosiv/blob/master/Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Вітаю!***
# ***Виконала: Косів Христина***
# ### Для аналізу датасету я обрала доволі складну тематику сьогодення, а саме оцінка сучасного рабства у світі. На платформі Kaggle обрала найновіший, що був оновлений 3 місяці тому.

# %% [markdown]
# Спочатку імпорт необхідних бібліотек:

# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **Для кращого результату, я поділила на три частини, а саме:**
#
# 1.   Інформація про датасет
# 2.   Очистка даних
# 3.   Розрахункові задачі

# %% [markdown]
# # **1. Інформація про датасет**

# %% [markdown]
# Завантажуємо і бачимо що датасет містить 180 рядків та 5 колонок:

# %%
df = pd.read_csv('Global_Slavery_Index_2023.csv')
df
# Out:
#                 Country      Population                   Region  \
# 0            Afghanistan    38,928,000      Asia and the Pacific
# 1                Albania     2,878,000   Europe and Central Asia
# 2                Algeria    43,851,000                    Africa
# 3                 Angola    32,866,000                    Africa
# 4    Antigua and Barbuda        98,000                  Americas
# ..                   ...            ...                      ...
# 175            Venezuela    28,436,000                  Americas
# 176             Viet Nam    97,339,000      Asia and the Pacific
# 177                Yemen    29,826,000               Arab States
# 178               Zambia    18,384,000                    Africa
# 179             Zimbabwe    14,863,000                    Africa
#
#      Estimated prevalence of modern slavery per 1,000 population  \
# 0                                                 13.0
# 1                                                 11.8
# ...

# %% [markdown]
# Для кращого ознайомлення виведемо 10 рядків (нумерація починається з нуля, бо індекси є описом):

# %%
df.head(10)
# Out:
#               Country      Population                   Region  \
# 0          Afghanistan    38,928,000      Asia and the Pacific
# 1              Albania     2,878,000   Europe and Central Asia
# 2              Algeria    43,851,000                    Africa
# 3               Angola    32,866,000                    Africa
# 4  Antigua and Barbuda        98,000                  Americas
# 5            Argentina    45,196,000                  Americas
# 6              Armenia     2,963,000   Europe and Central Asia
# 7            Australia    25,500,000      Asia and the Pacific
# 8              Austria     9,006,000   Europe and Central Asia
# 9           Azerbaijan    10,139,000   Europe and Central Asia
#
#    Estimated prevalence of modern slavery per 1,000 population  \
# 0                                               13.0
# 1                                               11.8
# 2                                                1.9
# ...

# %% [markdown]
# Виведемо завдяки кортеж з рядками та колонками:

# %%
df.shape
# Out:
# (180, 5)

# %% [markdown]
# Отримаймо інформацію, а саме, що тип колонок, пам'ять, яка використана, та найголовніше кількість ненульових значень:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 5 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Country                                                      180 non-null    object
#  1   Population                                                   180 non-null    object
#  2   Region                                                       180 non-null    object
#  3   Estimated prevalence of modern slavery per 1,000 population  160 non-null    float64
#  4   Estimated number of people in modern slavery                 160 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 7.2+ KB

# %% [markdown]
# Тепер опис: середнє значення, мінімальне, максимальне, кількість

# %%
df.describe()
# Out:
#        Estimated prevalence of modern slavery per 1,000 population
# count                                         160.000000
# mean                                            7.150625
# std                                            10.979375
# min                                             0.500000
# 25%                                             3.300000
# 50%                                             5.500000
# 75%                                             7.800000
# max                                           104.600000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['Estimated prevalence of modern slavery per 1,000 population'].plot(kind='hist', bins=20, title='Estimated prevalence of modern slavery per 1,000 population')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %% [markdown]
# Знайдемо кількість унікальних значень:

# %%
kilkist_unique= df.nunique()
kilkist_unique
# Out:
# Country                                                        180
# Population                                                     176
# Region                                                           5
# Estimated prevalence of modern slavery per 1,000 population     86
# Estimated number of people in modern slavery                   117
# dtype: int64

# %% [markdown]
# Виведемо усі рядки, де є нульові значення:

# %%
df[df.isnull().any(axis=1)]
# Out:
#                              Country   Population                   Region  \
# 4                 Antigua and Barbuda     98,000                  Americas
# 10                            Bahamas    393,000                  Americas
# 13                           Barbados    287,000                  Americas
# 16                             Belize    398,000                  Americas
# 22                  Brunei Darussalam    437,000      Asia and the Pacific
# 29                         Cape Verde        -                      Africa
# 53                               Fiji    896,000      Asia and the Pacific
# 70                            Iceland    341,000   Europe and Central Asia
# 92                      Liechtenstein        -     Europe and Central Asia
# 94                         Luxembourg    626,000   Europe and Central Asia
# 98                           Maldives    541,000      Asia and the Pacific
# ...

# %% [markdown]
# # **2. Очистка даних**

# %% [markdown]
# # **3. Розрахункові задачі**
